# %% [markdown]
# # Few-Shot Image Generation Demo
#
# This notebook demonstrates how to use the few-shot image generation models for:
# 1. Basic image generation
# 2. Few-shot adaptation
# 3. Model evaluation
#
# ## Setup
